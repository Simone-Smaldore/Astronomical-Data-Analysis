# %%
import pandas as pd
from astroquery.skyview import SkyView
import matplotlib.pyplot as plt

# %% [markdown]
# ### Getting info for andromeda galaxy(M31) with SDSSg

# %%
hdu = SkyView.get_images("M31", "SDSSg")[0][0]
hdu

# %% [markdown]
# ### Info about hdu file

# %%
hdu.header
# Out:
# SIMPLE  =                    T / Written by SkyView Tue Jan 30 04:31:24 EST 2024
# BITPIX  =                  -32 / 4 byte floating point
# NAXIS   =                    2 / Two dimensional image
# NAXIS1  =                  300 / Width of image
# NAXIS2  =                  300 / Height of image
# CRVAL1  =              10.6847 / Reference longitude
# CRVAL2  =              41.2688 / Reference latitude
# RADESYS = 'FK5     '           / Coordinate system
# EQUINOX =               2000.0 / Epoch of the equinox
# CTYPE1  = 'RA---TAN'           / Coordinates -- projection
# CTYPE2  = 'DEC--TAN'           / Coordinates -- projection
# CRPIX1  =                150.5 / X reference pixel
# CRPIX2  =                150.5 / Y reference pixel
# CDELT1  =             -0.00011 / X scale
# CDELT2  =              0.00011 / Y scale
# COMMENT
# COMMENT SkyView Survey metadata
# COMMENT
# COMMENT Provenance:  Sloan Digital Sky Survey Team
# ...

# %% [markdown]
# ### Getting the image

# %%
M31_pixels = hdu.data

# %%
print(f'Shape of the image: {M31_pixels.shape}')
# Out:
# Shape of the image: (300, 300)

# %%
plt.imshow(M31_pixels, cmap='gray', origin='lower')
